# %%
# 数字を2倍にして返す関数
def double(n):  #関数doubleを定義
    return n*2  #2倍にして返す
    
#呼び出し
print(double(10))
# Out:
# 20

# %%
# 数字を2倍にして返す関数
def double(n):
    # n を受け取って 2倍にして返す
    return n * 2

# 関数を呼び出して結果を表示
print(double(10))
